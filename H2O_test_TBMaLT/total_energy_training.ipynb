# %% [markdown]
# ## 1. Settings

# %% [markdown]
# ## 1.1 Setting up the environment

# %%
import torch
from tbmalt import Geometry, OrbitalInfo
from tbmalt.physics.dftb import Dftb2
from tbmalt.physics.dftb.feeds import SkFeed, SkfOccupationFeed, HubbardFeed, RepulsiveSplineFeed
from tbmalt.common.maths.interpolation import CubicSpline
from tbmalt.ml.loss_function import Loss, mse_loss

from ase.build import molecule

Tensor = torch.Tensor

# This must be set until typecasting from HDF5 databases has been implemented.
torch.set_default_dtype(torch.float64)

# %% [markdown]
# ## 1.2 Setting up the molecular systems for training

# %%
# Provide a list of moecules for training
molecule_names = ['H2O']

# Reference of target properties
targets = {'total_energy': torch.tensor(-4.0779379326)}

# Provide information about the orbitals on each atom; this is keyed by atomic
# numbers and valued by azimuthal quantum numbers like so:
#   {Z₁: [ℓᵢ, ℓⱼ, ..., ℓₙ], Z₂: [ℓᵢ, ℓⱼ, ..., ℓₙ], ...}
shell_dict = {1: [0], 6: [0, 1], 7: [0, 1], 8: [0, 1]}

# %% [markdown]
# ## 1.3 Setting up the model for training

# %%
# Before running this example, please use setup.ipynb to download the parameter set needed
# Location at which the DFTB parameter set database is located
parameter_db_path = 'mio.h5'

# Type of ML model
model = 'spline'

# Whether performing model fitting
fit_model = True

# Number of training cycles
number_of_epochs = 500

# Learning rate
lr = 0.002

# Loss function
loss_func = mse_loss

# %% [markdown]
# ## 1.4 Setting up the DFTB calculator

# %% [markdown]
# ## 1.4.1 Input the molecular systems

# %%
device = torch.device('cpu')
# Construct the `Geometry` and `OrbitalInfo` objects. The former is analogous
# to the ase.Atoms object while the latter provides information about what
# orbitals are present and which atoms they belong to.
geometry = Geometry(
        torch.tensor([8,1,1], device=device),
        torch.tensor([
            [0.00000000, -0.71603315, -0.00000000],
            [0.00000000, -0.14200298, 0.77844804 ],
            [-0.00000000, -0.14200298, -0.77844804]],
            device=device),units='a')

orbs = OrbitalInfo(geometry.atomic_numbers, shell_dict)

print('Geometry:', geometry)
print('OrbitalInfo:', orbs)

# Identify which species are present
species = torch.unique(geometry.atomic_numbers)
# Strip out padding species and convert to a standard list.
species = species[species != 0].tolist()
# Out:
# Geometry: Geometry(OH2)
# OrbitalInfo: <tbmalt.structures.orbitalinfo.OrbitalInfo object at 0x7f039dc9a150>

# %% [markdown]
# ## 1.4.2 Loading of the DFTB parameters into their associated feed objects

# %%
# Load the Hamiltonian feed model
h_feed = SkFeed.from_database(parameter_db_path, species, 'hamiltonian',
                              interpolation=CubicSpline)

# Load the overlap feed model
s_feed = SkFeed.from_database(parameter_db_path, species, 'overlap',
                              interpolation=CubicSpline)

# Load the occupation feed object
o_feed = SkfOccupationFeed.from_database(parameter_db_path, species)

# Load the Hubbard-U feed object
u_feed = HubbardFeed.from_database(parameter_db_path, species, requires_grad=True)

#When add r_feed, loss: tensor(1.4389e-09) on epoch 0
#r_feed = RepulsiveSplineFeed.from_database(parameter_db_path, species)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[214], line 5
#       1 # Load the Hamiltonian feed model
#       2 h_feed = SkFeed.from_database(parameter_db_path, species, 'hamiltonian',
#       3                               interpolation=CubicSpline)
# ----> 5 print('Hamiltonian feed:', h_feed.values)
#       7 # Load the overlap feed model
#       8 s_feed = SkFeed.from_database(parameter_db_path, species, 'overlap',
#       9                               interpolation=CubicSpline)
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/torch/nn/modules/module.py:1928, in Module.__getattr__(self, name)
#    1926     if name in modules:
#    1927         return modules[name]
# -> 1928 raise AttributeError(
#    1929     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1930 )
#
# AttributeError: 'SkFeed' object has no attribute 'values'

# %% [markdown]
# ## 1.4.3 Constructing the SCC-DFTB calculator

# %%
dftb_calculator = Dftb2(h_feed, s_feed, o_feed, u_feed, filling_scheme=None)

# %% [markdown]
# ## 2. Data preparation

# %%
# Define a delegate to obtain predictions from the trained model
def prediction_delegate(calculator, targets, **kwargs):
     predictions = dict()
     predictions["energy"] = calculator.total_energy
     
     return predictions

# %%
# Define a delegate to obtain reference results
def reference_delegate(calculator, targets, **kwargs):
     references = dict()
     references["energy"] = targets['total_energy']

     return references

# %% [markdown]
# ## 3. Model training

# %%
# Define parameters to optimize
variable = u_feed.hubbard_us.parameters()

# %%
# Define the loss entity
loss_entity = Loss(prediction_delegate, reference_delegate,
                   loss_functions=loss_func, reduction='mean')

# %%
# Define optimizer
optimizer = getattr(torch.optim, 'Adam')(params=variable, lr=lr)

# %%
# Execution
loss_list = []
loss_list.append(0)
for epoch in range(number_of_epochs):
    _loss = 0
    print('epoch', epoch)
    dftb_calculator(geometry, orbs, grad_mode="direct")
    total_loss, raw_losses = loss_entity(dftb_calculator, targets)
    _loss = _loss + total_loss
    optimizer.zero_grad()
    _loss.retain_grad()

    # Invoke the autograd engine
    _loss.backward(retain_graph=True)

    # Update the model
    optimizer.step()
    print("loss:", _loss)
    loss_list.append(_loss.detach())
# Out:
# epoch 0
# loss: tensor(0.0053, grad_fn=<AddBackward0>)
# epoch 1
# loss: tensor(0.0052, grad_fn=<AddBackward0>)
# epoch 2
# loss: tensor(0.0052, grad_fn=<AddBackward0>)
# epoch 3
# loss: tensor(0.0052, grad_fn=<AddBackward0>)
# epoch 4
# loss: tensor(0.0052, grad_fn=<AddBackward0>)
# epoch 5
# loss: tensor(0.0051, grad_fn=<AddBackward0>)
# epoch 6
# loss: tensor(0.0051, grad_fn=<AddBackward0>)
# epoch 7
# loss: tensor(0.0051, grad_fn=<AddBackward0>)
# epoch 8
# loss: tensor(0.0050, grad_fn=<AddBackward0>)
# epoch 9
# loss: tensor(0.0050, grad_fn=<AddBackward0>)
# epoch 10
# loss: tensor(0.0050, grad_fn=<AddBackward0>)
# epoch 11
# loss: tensor(0.0049, grad_fn=<AddBackward0>)
# epoch 12
# loss: tensor(0.0049, grad_fn=<AddBackward0>)
# epoch 13
# loss: tensor(0.0049, grad_fn=<AddBackward0>)
# epoch 14
# loss: tensor(0.0048, grad_fn=<AddBackward0>)
# epoch 15
# loss: tensor(0.0048, grad_fn=<AddBackward0>)
# epoch 16
# loss: tensor(0.0048, grad_fn=<AddBackward0>)
# epoch 17
# loss: tensor(0.0047, grad_fn=<AddBackward0>)
# epoch 18
# loss: tensor(0.0047, grad_fn=<AddBackward0>)
# epoch 19
# loss: tensor(0.0047, grad_fn=<AddBackward0>)
# epoch 20
# loss: tensor(0.0046, grad_fn=<AddBackward0>)
# epoch 21
# loss: tensor(0.0046, grad_fn=<AddBackward0>)
# epoch 22
# loss: tensor(0.0046, grad_fn=<AddBackward0>)
# epoch 23
# loss: tensor(0.0045, grad_fn=<AddBackward0>)
# epoch 24
# loss: tensor(0.0045, grad_fn=<AddBackward0>)
# epoch 25
# loss: tensor(0.0044, grad_fn=<AddBackward0>)
# epoch 26
# loss: tensor(0.0044, grad_fn=<AddBackward0>)
# epoch 27
# loss: tensor(0.0044, grad_fn=<AddBackward0>)
# epoch 28
# loss: tensor(0.0043, grad_fn=<AddBackward0>)
# epoch 29
# loss: tensor(0.0043, grad_fn=<AddBackward0>)
# epoch 30
# loss: tensor(0.0043, grad_fn=<AddBackward0>)
# epoch 31
# loss: tensor(0.0042, grad_fn=<AddBackward0>)
# epoch 32
# loss: tensor(0.0042, grad_fn=<AddBackward0>)
# epoch 33
# loss: tensor(0.0041, grad_fn=<AddBackward0>)
# epoch 34
# loss: tensor(0.0041, grad_fn=<AddBackward0>)
# epoch 35
# loss: tensor(0.0041, grad_fn=<AddBackward0>)
# epoch 36
# loss: tensor(0.0040, grad_fn=<AddBackward0>)
# epoch 37
# loss: tensor(0.0040, grad_fn=<AddBackward0>)
# epoch 38
# loss: tensor(0.0040, grad_fn=<AddBackward0>)
# epoch 39
# loss: tensor(0.0039, grad_fn=<AddBackward0>)
# epoch 40
# loss: tensor(0.0039, grad_fn=<AddBackward0>)
# epoch 41
# loss: tensor(0.0038, grad_fn=<AddBackward0>)
# epoch 42
# loss: tensor(0.0038, grad_fn=<AddBackward0>)
# epoch 43
# loss: tensor(0.0038, grad_fn=<AddBackward0>)
# epoch 44
# loss: tensor(0.0037, grad_fn=<AddBackward0>)
# epoch 45
# loss: tensor(0.0037, grad_fn=<AddBackward0>)
# epoch 46
# loss: tensor(0.0036, grad_fn=<AddBackward0>)
# epoch 47
# loss: tensor(0.0036, grad_fn=<AddBackward0>)
# epoch 48
# loss: tensor(0.0036, grad_fn=<AddBackward0>)
# epoch 49
# loss: tensor(0.0035, grad_fn=<AddBackward0>)
# epoch 50
# loss: tensor(0.0035, grad_fn=<AddBackward0>)
# epoch 51
# loss: tensor(0.0035, grad_fn=<AddBackward0>)
# epoch 52
# loss: tensor(0.0034, grad_fn=<AddBackward0>)
# epoch 53
# loss: tensor(0.0034, grad_fn=<AddBackward0>)
# epoch 54
# loss: tensor(0.0033, grad_fn=<AddBackward0>)
# epoch 55
# loss: tensor(0.0033, grad_fn=<AddBackward0>)
# epoch 56
# loss: tensor(0.0033, grad_fn=<AddBackward0>)
# epoch 57
# loss: tensor(0.0032, grad_fn=<AddBackward0>)
# epoch 58
# loss: tensor(0.0032, grad_fn=<AddBackward0>)
# epoch 59
# loss: tensor(0.0032, grad_fn=<AddBackward0>)
# epoch 60
# loss: tensor(0.0031, grad_fn=<AddBackward0>)
# epoch 61
# loss: tensor(0.0031, grad_fn=<AddBackward0>)
# epoch 62
# loss: tensor(0.0031, grad_fn=<AddBackward0>)
# epoch 63
# loss: tensor(0.0030, grad_fn=<AddBackward0>)
# epoch 64
# loss: tensor(0.0030, grad_fn=<AddBackward0>)
# epoch 65
# loss: tensor(0.0029, grad_fn=<AddBackward0>)
# epoch 66
# loss: tensor(0.0029, grad_fn=<AddBackward0>)
# epoch 67
# loss: tensor(0.0029, grad_fn=<AddBackward0>)
# epoch 68
# loss: tensor(0.0028, grad_fn=<AddBackward0>)
# epoch 69
# loss: tensor(0.0028, grad_fn=<AddBackward0>)
# epoch 70
# loss: tensor(0.0028, grad_fn=<AddBackward0>)
# epoch 71
# loss: tensor(0.0027, grad_fn=<AddBackward0>)
# epoch 72
# loss: tensor(0.0027, grad_fn=<AddBackward0>)
# epoch 73
# loss: tensor(0.0027, grad_fn=<AddBackward0>)
# epoch 74
# loss: tensor(0.0026, grad_fn=<AddBackward0>)
# epoch 75
# loss: tensor(0.0026, grad_fn=<AddBackward0>)
# epoch 76
# loss: tensor(0.0026, grad_fn=<AddBackward0>)
# epoch 77
# loss: tensor(0.0025, grad_fn=<AddBackward0>)
# epoch 78
# loss: tensor(0.0025, grad_fn=<AddBackward0>)
# epoch 79
# loss: tensor(0.0025, grad_fn=<AddBackward0>)
# epoch 80
# loss: tensor(0.0024, grad_fn=<AddBackward0>)
# epoch 81
# loss: tensor(0.0024, grad_fn=<AddBackward0>)
# epoch 82
# loss: tensor(0.0024, grad_fn=<AddBackward0>)
# epoch 83
# loss: tensor(0.0023, grad_fn=<AddBackward0>)
# epoch 84
# loss: tensor(0.0023, grad_fn=<AddBackward0>)
# epoch 85
# loss: tensor(0.0023, grad_fn=<AddBackward0>)
# epoch 86
# loss: tensor(0.0023, grad_fn=<AddBackward0>)
# epoch 87
# loss: tensor(0.0022, grad_fn=<AddBackward0>)
# epoch 88
# loss: tensor(0.0022, grad_fn=<AddBackward0>)
# epoch 89
# loss: tensor(0.0022, grad_fn=<AddBackward0>)
# epoch 90
# loss: tensor(0.0021, grad_fn=<AddBackward0>)
# epoch 91
# loss: tensor(0.0021, grad_fn=<AddBackward0>)
# epoch 92
# loss: tensor(0.0021, grad_fn=<AddBackward0>)
# epoch 93
# loss: tensor(0.0021, grad_fn=<AddBackward0>)
# epoch 94
# loss: tensor(0.0020, grad_fn=<AddBackward0>)
# epoch 95
# loss: tensor(0.0020, grad_fn=<AddBackward0>)
# epoch 96
# loss: tensor(0.0020, grad_fn=<AddBackward0>)
# epoch 97
# loss: tensor(0.0019, grad_fn=<AddBackward0>)
# epoch 98
# loss: tensor(0.0019, grad_fn=<AddBackward0>)
# epoch 99
# loss: tensor(0.0019, grad_fn=<AddBackward0>)
# epoch 100
# loss: tensor(0.0019, grad_fn=<AddBackward0>)
# epoch 101
# loss: tensor(0.0018, grad_fn=<AddBackward0>)
# epoch 102
# loss: tensor(0.0018, grad_fn=<AddBackward0>)
# epoch 103
# loss: tensor(0.0018, grad_fn=<AddBackward0>)
# epoch 104
# loss: tensor(0.0018, grad_fn=<AddBackward0>)
# epoch 105
# loss: tensor(0.0018, grad_fn=<AddBackward0>)
# epoch 106
# loss: tensor(0.0017, grad_fn=<AddBackward0>)
# epoch 107
# loss: tensor(0.0017, grad_fn=<AddBackward0>)
# epoch 108
# loss: tensor(0.0017, grad_fn=<AddBackward0>)
# epoch 109
# loss: tensor(0.0017, grad_fn=<AddBackward0>)
# epoch 110
# loss: tensor(0.0016, grad_fn=<AddBackward0>)
# epoch 111
# loss: tensor(0.0016, grad_fn=<AddBackward0>)
# epoch 112
# loss: tensor(0.0016, grad_fn=<AddBackward0>)
# epoch 113
# loss: tensor(0.0016, grad_fn=<AddBackward0>)
# epoch 114
# loss: tensor(0.0016, grad_fn=<AddBackward0>)
# epoch 115
# loss: tensor(0.0015, grad_fn=<AddBackward0>)
# epoch 116
# loss: tensor(0.0015, grad_fn=<AddBackward0>)
# epoch 117
# loss: tensor(0.0015, grad_fn=<AddBackward0>)
# epoch 118
# loss: tensor(0.0015, grad_fn=<AddBackward0>)
# epoch 119
# loss: tensor(0.0015, grad_fn=<AddBackward0>)
# epoch 120
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 121
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 122
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 123
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 124
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 125
# loss: tensor(0.0014, grad_fn=<AddBackward0>)
# epoch 126
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 127
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 128
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 129
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 130
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 131
# loss: tensor(0.0013, grad_fn=<AddBackward0>)
# epoch 132
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 133
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 134
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 135
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 136
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 137
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 138
# loss: tensor(0.0012, grad_fn=<AddBackward0>)
# epoch 139
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 140
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 141
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 142
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 143
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 144
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 145
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 146
# loss: tensor(0.0011, grad_fn=<AddBackward0>)
# epoch 147
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 148
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 149
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 150
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 151
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 152
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 153
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 154
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 155
# loss: tensor(0.0010, grad_fn=<AddBackward0>)
# epoch 156
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 157
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 158
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 159
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 160
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 161
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 162
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 163
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 164
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 165
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 166
# loss: tensor(0.0009, grad_fn=<AddBackward0>)
# epoch 167
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 168
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 169
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 170
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 171
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 172
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 173
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 174
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 175
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 176
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 177
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 178
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 179
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 180
# loss: tensor(0.0008, grad_fn=<AddBackward0>)
# epoch 181
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 182
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 183
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 184
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 185
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 186
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 187
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 188
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 189
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 190
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 191
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 192
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 193
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 194
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 195
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 196
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 197
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 198
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 199
# loss: tensor(0.0007, grad_fn=<AddBackward0>)
# epoch 200
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 201
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 202
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 203
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 204
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 205
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 206
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 207
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 208
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 209
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 210
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 211
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 212
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 213
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 214
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 215
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 216
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 217
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 218
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 219
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 220
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 221
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 222
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 223
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 224
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 225
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 226
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 227
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 228
# loss: tensor(0.0006, grad_fn=<AddBackward0>)
# epoch 229
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 230
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 231
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 232
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 233
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 234
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 235
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 236
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 237
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 238
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 239
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 240
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 241
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 242
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 243
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 244
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 245
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 246
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 247
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 248
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 249
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 250
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 251
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 252
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 253
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 254
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 255
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 256
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 257
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 258
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 259
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 260
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 261
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 262
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 263
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 264
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 265
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 266
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 267
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 268
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 269
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 270
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 271
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 272
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 273
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 274
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 275
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 276
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 277
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 278
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 279
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 280
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 281
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 282
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 283
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 284
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 285
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 286
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 287
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 288
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 289
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 290
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 291
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 292
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 293
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 294
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 295
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 296
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 297
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 298
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 299
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 300
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 301
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 302
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 303
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 304
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 305
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 306
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 307
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 308
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 309
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 310
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 311
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 312
# loss: tensor(0.0005, grad_fn=<AddBackward0>)
# epoch 313
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 314
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 315
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 316
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 317
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 318
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 319
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 320
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 321
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 322
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 323
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 324
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 325
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 326
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 327
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 328
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 329
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 330
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 331
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 332
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 333
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 334
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 335
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 336
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 337
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 338
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 339
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 340
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 341
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 342
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 343
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 344
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 345
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 346
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 347
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 348
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 349
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 350
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 351
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 352
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 353
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 354
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 355
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 356
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 357
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 358
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 359
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 360
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 361
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 362
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 363
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 364
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 365
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 366
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 367
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 368
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 369
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 370
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 371
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 372
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 373
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 374
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 375
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 376
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 377
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 378
# loss: tensor(0.0004, grad_fn=<AddBackward0>)
# epoch 379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[209], line 7
#       5 _loss = 0
#       6 print('epoch', epoch)
# ----> 7 dftb_calculator(geometry, orbs, grad_mode="direct")
#       8 total_loss, raw_losses = loss_entity(dftb_calculator, targets)
#       9 _loss = _loss + total_loss
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/ml/module.py:85, in Calculator.__call__(self, geometry, orbs, cache, **kwargs)
#      82     self.reset()
#      83     self._geometry, self._orbs = geometry, orbs
# ---> 85 return self.forward(cache=cache, **kwargs)
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/physics/dftb/__init__.py:1310, in Dftb2.forward(self, cache, grad_mode, **kwargs)
#    1301 # Step 2: SCC Cycle
#    1302 # The following block performs the actual SCC cycle. However, different
#    1303 # approaches are needed depending on what gradient mode is to be used.
#    1304 # The "direct" approach carries out the SCC cycle without any special
#    1305 # handling. Therefor the gradient will pass through the full SCC cycle.
#    1306 if grad_mode == "direct":
#    1307     (q_out, self._hamiltonian, self.eig_values, self.eig_vectors,
#    1308      self.rho) = Dftb2.scc_cycle(
#    1309         self.q_zero_res, self.orbs, self.core_hamiltonian,
# -> 1310         self.overlap, self.gamma, **kwargs_in)
#    1312 # In the "last step" approach the SCC cycle is performed outside the
#    1313 # purview of the graph and is used only to obtain the converged
#    1314 # charges. Following this, an additional "SCC step" is performed within
#    1315 # the PyTorch graph. The emulates what would happen if one were to
#    1316 # perform the SCC cycle using a highly accurate initial guess for the
#    1317 # charges.
#    1318 elif grad_mode == "last_step":
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/physics/dftb/__init__.py:806, in Dftb2.overlap(self)
#     803 # Check to see if the overlap matrix has already been constructed. If
#     804 # not then construct it.
#     805 if self._overlap is None:
# --> 806     self._overlap = self.s_feed.matrix_from_calculator(self)
#     808 # Return the cached overlap matrix.
#     809 return self._overlap
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/ml/integralfeeds.py:298, in IntegralFeed.matrix_from_calculator(self, calculator, **kwargs)
#     263 def matrix_from_calculator(self, calculator: Calculator, **kwargs):
#     264     """Construct the hermitian matrix associated with this feed.
#     265
#     266     This method extracts the required arguments from the supplied
#    (...)    295             enhancing the overall maintainability and debuggability.
#     296     """
# --> 298     return self.matrix(calculator.geometry, calculator.orbs, **kwargs)
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/ml/integralfeeds.py:253, in IntegralFeed.matrix(self, geometry, orbs, **kwargs)
#     250 blk_idx = self.atomic_block_indices(a_idx_l, b_idx_l, orbs)
#     252 # Construct the blocks for these interactions
# --> 253 blks = self.blocks(a_idx_l, b_idx_l, geometry, orbs, **kwargs)
#     255 # Assign data to the matrix. As on-site blocks are not masked out
#     256 # during the transpose assignment the transpose assignment must
#     257 # be done first (this is only matters for complex diagonal blocks).
#     258 mat.transpose(-1, -2)[*blk_idx] = blks.conj()
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/tbmalt/physics/dftb/feeds.py:862, in SkFeed.blocks(self, atomic_idx_1, atomic_idx_2, geometry, orbs, **kwargs)
#     859     flip = False
#     861 # Construct the tensor into which results are to be placed
# --> 862 n_rows, n_cols = orbs.n_orbs_on_species(torch.stack((z_1, z_2)))
#     863 blks = torch.zeros(len(atomic_idx_1), n_rows, n_cols, dtype=self.dtype,
#     864                    device=self.device)
#     866 # Identify which are on-site blocks and which are off-site
#
# File ~/venvs/bachelor/lib/python3.11/site-packages/torch/_tensor.py:1144, in Tensor.__iter__(self)
#    1134         warnings.warn(
#    1135             "Using len to get tensor shape might cause the trace to be incorrect. "
#    1136             "Recommended usage would be tensor.shape[0]. "
#    (...)   1140             stacklevel=2,
#    1141         )
#    1142     return self.shape[0]
# -> 1144 def __iter__(self):
#    1145     # NB: we use 'imap' and not 'map' here, so that in Python 2 we get a
#    1146     # generator and don't eagerly perform all the indexes.  This could
#    1147     # save us work, and also helps keep trace ordering deterministic
#    1148     # (e.g., if you zip(*hiddens), the eager map will force all the
#    1149     # indexes of hiddens[0] before hiddens[1], while the generator
#    1150     # map will interleave them.)
#    1151     # NB: We have intentionally skipped __torch_function__ dispatch here.
#    1152     # See gh-54457
#    1153     if self.dim() == 0:
#    1154         raise TypeError("iteration over a 0-d tensor")
#
# KeyboardInterrupt:

# %%
# Plot the loss
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["font.family"] = "Arial"
plt.rcParams["axes.linewidth"] = 1.5
plt.tick_params(direction='in', labelsize='26', width=1.5, length=5, top='on',
                    right='on', zorder=10)
plt.plot(torch.linspace(1, number_of_epochs, number_of_epochs),
         loss_list[1:])
plt.xlabel("Iteration", fontsize=28)
plt.ylabel("Loss",  fontsize=28)
#plt.savefig('loss_hubbard.pdf', dpi=500, bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
